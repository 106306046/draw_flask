# %%
import requests

# %%
from PIL import Image
import io
import base64

# %%
image = Image.open('./input_5.png').resize((800,450))
image
# Out:
# <PIL.Image.Image image mode=RGBA size=800x450>

# %%
def return_img_base64(img):
    # 將圖片轉換為 Base64 字串
    img_byte_array = io.BytesIO()
    img.save(img_byte_array, format='JPEG')
    img_base64 = base64.b64encode(img_byte_array.getvalue()).decode('utf-8')
    return img_base64

# %%
base64_img = return_img_base64(image.convert('RGB'))

# %%
domain = 'http://127.0.0.1:8001'+'/upload'
payload_dct = {
    "image": base64_img 
}

# %%
r = requests.post(domain, json=payload_dct)
r.status_code
r.json()
# Out:
# {'base64_image': '...'}
